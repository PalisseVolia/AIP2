# %%
import keras
import pandas as pd
import matplotlib.pyplot as plt

fashion_mnist =  keras.datasets.fashion_mnist

(X_trainval, y_trainval), (X_test, y_test) = fashion_mnist.load_data()

X_valid = X_trainval[:5000] / 255.0,
X_train = X_trainval[5000:] / 255.0   # Scaling from (0~255) to (0,1)

y_valid = y_trainval[:5000]
y_train = y_trainval[5000:]

# %%
# =========================================================
# Assignment One
# =========================================================

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28,28]))
model.add(keras.layers.Dense(512, activation="relu"))
model.add(keras.layers.Dense(512, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 10)                5130
#
# ...
# Total params: 669706 (2.55 MB)
# Trainable params: 669706 (2.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# =========================================================
# Assignment Two
# =========================================================

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam",
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs = 20, batch_size = 64, validation_data = (X_valid, y_valid), verbose=0)

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
# =========================================================
# Assignment Three
# =========================================================

model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 76.8691 - accuracy: 0.8681
# [76.86914825439453, 0.8680999875068665]

# %%
# =========================================================
# Assignment Four
# =========================================================

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28,28]))
model.add(keras.layers.Dense(512))
model.add(keras.layers.Dense(512))
model.add(keras.layers.Dense(10, activation="softmax"))
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam",
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs = 20, batch_size = 64, validation_data = (X_valid, y_valid), verbose=0)

model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 129.1934 - accuracy: 0.7632
# [129.19342041015625, 0.7631999850273132]

# %%
# =========================================================
# Assignment Five
# =========================================================

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28,28]))
model.add(keras.layers.Dense(10, activation="softmax"))

model.summary()

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam",
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs = 20, batch_size = 64, validation_data = (X_valid, y_valid), verbose=0)

model.evaluate(X_test, y_test)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 10)                7850
#
# ...
# Total params: 7850 (30.66 KB)
# Trainable params: 7850 (30.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 313/313 [==============================] - 1s 2ms/step - loss: 93.3044 - accuracy: 0.7962
# [93.304443359375, 0.7961999773979187]
